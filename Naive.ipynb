# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarissmona/ML-DL-Tasks/blob/main/Naive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# importing all libraries

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# # #Load dataset

# %%
data = load_iris()
X = data.data
y = data.target
#The dataset contains 150 flower samples.
#Features (X):Each sample has 4 features:Sepal length,Sepal width,Petal length
#Petal width:Example: [5.1, 3.5, 1.4, 0.2]
#Labels (y) :y = data.target,Target values represent flower classes.
#0 → Setosa,1 → Versicolor,2 → Virginica

# %% [markdown]
# # Split *dataset*

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#120 samples → Training
#30 samples → Testing
# Train model
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # Prediction

# %%
y_pred = model.predict(X_test)
print(y_pred)
#The trained model predicts flower types for the test dataset. Example prediction:
#[0 1 2 1 0 2 ...]
# Out:
# [2 0 2 2 0 2 0 2 1 2 1 2 2 0 2 0 1 1 2 1 1 1 0 1 2 2 0 1 0 0]

# %%
# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9666666666666667
