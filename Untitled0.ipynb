# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarissmona/ML-DL-Tasks/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print("Tensor flow",tf.__version__)
# Out:
# Tensor flow 2.19.0

# %%
# !pip install torch

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)

# %%
plt.imshow(x_train[0], cmap='gray')
plt.title("Label: {}".format(y_train[0]))
plt.show()

# %%
x_train = x_train/255
x_test = x_test/255

# %%
print("Minimum Value", x_train.min())
print("Maximum Value", x_train.max())
# Out:
# Minimum Value 0.0
# Maximum Value 1.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
tf.keras.layers.Rescaling(1./255)
# Out:
# <Rescaling name=rescaling, built=False>

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
sample = x_train[0].reshape((1,28,28,1))

# %%
for batch in datagen.flow(sample, batch_size=1):
    plt.imshow(batch[0].reshape(28,28), cmap='gray')
    plt.show()
    break

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(x_train[2050], cmap='Greens')
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(batch[0].reshape(28,28), cmap='Greens')
plt.title("Augmented Image")

plt.show()

# %%
#Generate augmented images
aug_iter = datagen.flow(sample, batch_size=1)

# Plot 9 images
plt.figure(figsize=(6,6))

for i in range(9):
    plt.subplot(3,3,i+1)
    batch = next(aug_iter)
    plt.imshow(batch[0].reshape(28,28), cmap='gray')
    plt.axis('off')

plt.suptitle("Augmented Images")
plt.show()
